# %%
# !git clone https://github.com/divamgupta/stable-diffusion-tensorflow.git
# Out:
# Cloning into 'stable-diffusion-tensorflow'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 73 (delta 28), reused 50 (delta 10), pack-reused 0
# Unpacking objects: 100% (73/73), done.

# %%
# !pip install --upgrade git+https://github.com/divamgupta/stable-diffusion-tensorflow
# !pip install tensorflow-addons
# !pip install ftfy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/divamgupta/stable-diffusion-tensorflow to /tmp/pip-req-build-5no9mh55
#   Running command git clone -q https://github.com/divamgupta/stable-diffusion-tensorflow /tmp/pip-req-build-5no9mh55
# ...
#   Created wheel for stable-diffusion-tf: filename=stable_diffusion_tf-0.1-py3-none-any.whl size=16124 sha256=aa15376cb6085a9f5beed4759202c2df09115dfc86de051ad4921aaa68a3dd12
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qgc7_w5b/wheels/83/77/d2/8a0a1433ec2e598f908dbf726108785e86c1c1421c8f896f87
# Successfully built stable-diffusion-tf
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.1 MB 25.8 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 53 kB 938 kB/s
# ...

# %%
from stable_diffusion_tf.stable_diffusion import get_model, text2image
text_encoder, diffusion_model, decoder = get_model(512, 512, download_weights=True)

img = text2image("An astronaut riding a hourse" , 
	img_height=512, 
	img_width=512,  
	text_encoder=text_encoder, 
	diffusion_model=diffusion_model, 
	decoder=decoder
)
# %cd /content/
# Out:
# running for [1, 41, 81, 121, 161, 201, 241, 281, 321, 361, 401, 441, 481, 521, 561, 601, 641, 681, 721, 761, 801, 841, 881, 921, 961] timesteps
#   0   1: 100%|██████████| 25/25 [00:38<00:00,  1.53s/it]
# /content

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
cv.imwrite("/tmp/a.png" , img[0][... , ::-1])
# Out:
# True

# %%
img = text2image("Cross-eyed dog" , 
	img_height=512, 
	img_width=512,  
	text_encoder=text_encoder, 
	diffusion_model=diffusion_model, 
	decoder=decoder
)
# %cd /content/
cv.imwrite("/tmp/b.png" , img[0][... , ::-1])
ImagesGenerated=cv.imread("/tmp/b.png")
cv2_imshow(ImagesGenerated)
# Out:
# running for [1, 41, 81, 121, 161, 201, 241, 281, 321, 361, 401, 441, 481, 521, 561, 601, 641, 681, 721, 761, 801, 841, 881, 921, 961] timesteps
#   0   1: 100%|██████████| 25/25 [00:38<00:00,  1.53s/it]
# /content
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FDE4A10D990>

# %%
img = text2image("Polar bear carrying a coffee mug" , 
	img_height=512, 
	img_width=512,  
	text_encoder=text_encoder, 
	diffusion_model=diffusion_model, 
	decoder=decoder
)
# %cd /content/
cv.imwrite("/tmp/b.png" , img[0][... , ::-1])
ImagesGenerated=cv.imread("/tmp/b.png")
cv2_imshow(ImagesGenerated)
# Out:
# running for [1, 41, 81, 121, 161, 201, 241, 281, 321, 361, 401, 441, 481, 521, 561, 601, 641, 681, 721, 761, 801, 841, 881, 921, 961] timesteps
#   0   1: 100%|██████████| 25/25 [00:38<00:00,  1.53s/it]
# /content
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FE2424C6750>

# %%
img = text2image("A cat has a hat and sunglass" , 
	img_height=512, 
	img_width=512,  
	text_encoder=text_encoder, 
	diffusion_model=diffusion_model, 
	decoder=decoder
)
# %cd /content/
cv.imwrite("/tmp/b.png" , img[0][... , ::-1])
ImagesGenerated=cv.imread("/tmp/b.png")
cv2_imshow(ImagesGenerated)
# Out:
# running for [1, 41, 81, 121, 161, 201, 241, 281, 321, 361, 401, 441, 481, 521, 561, 601, 641, 681, 721, 761, 801, 841, 881, 921, 961] timesteps
#   0   1: 100%|██████████| 25/25 [00:42<00:00,  1.68s/it]
# /content
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FE140C2EFD0>

# %% [markdown]
# Let's creat a strange cat :)

# %%
img = text2image("cat carrying a flag " , 
	img_height=512, 
	img_width=512,  
	text_encoder=text_encoder, 
	diffusion_model=diffusion_model, 
	decoder=decoder
)
# %cd /content/
cv.imwrite("/tmp/b.png" , img[0][... , ::-1])
ImagesGenerated=cv.imread("/tmp/b.png")
cv2_imshow(ImagesGenerated)
# Out:
# running for [1, 41, 81, 121, 161, 201, 241, 281, 321, 361, 401, 441, 481, 521, 561, 601, 641, 681, 721, 761, 801, 841, 881, 921, 961] timesteps
#   0   1: 100%|██████████| 25/25 [00:38<00:00,  1.56s/it]
# /content
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FDE45597ED0>
